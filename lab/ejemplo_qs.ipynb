# %%
import pandas


df = pandas.read_excel('Bose Schedule - 2024-04-19.xlsx', engine='openpyxl', sheet_name='Bose Master Fixture List', skiprows=3)
print(df)
# Out:
#          Account     Store Name    AL No. Break/Fix Partner Maint. SLA  \
# 0    BEST BUY US  MINNETONKA MN  BBUY0004               MTI     2.Gold
# 1    BEST BUY US   ROSEVILLE MN  BBUY0007               MTI     2.Gold
# 2    BEST BUY US  BURNSVILLE MN  BBUY0008               MTI   3.Silver
# 3    BEST BUY US   MAPLEWOOD MN  BBUY0010               MTI   3.Silver
# 4    BEST BUY US    ST CLOUD MN  BBUY0012               MTI   3.Silver
# ..           ...            ...       ...               ...        ...
# 946          NaN            NaN       NaN               NaN        NaN
# 947          NaN            NaN       NaN               NaN        NaN
# 948          NaN            NaN       NaN               NaN        NaN
# 949          NaN            NaN       NaN               NaN        NaN
# 950          NaN            NaN       NaN               NaN        NaN
#
#     SAP Ship-To  BBY No.              Address         City State  ...  \
# ...
