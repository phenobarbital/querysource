# %%
import pandas

# %%
df = pandas.read_excel('Bose Schedule - 2024-04-19.xlsx')

# %%
print(df.head())
# Out:
#                            Type  (Multiple Items)  Unnamed: 2  Unnamed: 3
# 0  filtered to filled positions               NaN         NaN         NaN
# 1                           NaN               NaN         NaN         NaN
# 2                           NaN               NaN         NaN         NaN
# 3                           NaN               NaN         NaN         NaN
# 4                           NaN               NaN         NaN         NaN

# %%
from querysource.queries.qs import QS
st = QS(slug='walmart_stores')
stores = await st.query()
print('STORES > ', stores)
# Out:
# [DEBUG] 2024-05-21 18:36:31,147 QuerySource|68 ::                 Initialize Slug: walmart_stores
# [DEBUG] 2024-05-21 18:36:31,147 QuerySource(qs.py:68) :: Initialize Slug: walmart_stores
# [DEBUG] 2024-05-21 18:36:31,148 QuerySource|145 ::                 Starting Slug-based Query: walmart_stores
# [DEBUG] 2024-05-21 18:36:31,148 QuerySource(qs.py:145) :: Starting Slug-based Query: walmart_stores
# [DEBUG] 2024-05-21 18:36:31,198 DB.pg|582 ::                 Initialized on: 1716309391.198008
# [DEBUG] 2024-05-21 18:36:31,198 DB.pg(pg.py:582) :: Initialized on: 1716309391.198008
# [DEBUG] 2024-05-21 18:36:31,199 QS.Connection|377 ::                 ::: Getting Slug walmart_stores from public.queries
# [DEBUG] 2024-05-21 18:36:31,199 QS.Connection(connections.py:377) :: ::: Getting Slug walmart_stores from public.queries
# [DEBUG] 2024-05-21 18:36:31,218 QS.Connection|415 ::                 Getting Slug, Execution Time: 0.068ms
#
# ...

# %%
Aqui cargamos la data de Store:

# %%
data = QS(slug='kingwater_viba_stores')
# Out:
# [DEBUG] 2024-05-17 15:26:50,233 QuerySource|68 ::                 Initialize Slug: kingwater_viba_stores
# [DEBUG] 2024-05-17 15:26:50,233 QuerySource(qs.py:68) :: Initialize Slug: kingwater_viba_stores

# %%
from asyncdb import AsyncDB
from navigator.conf import default_dsn
db = AsyncDB('pg', dsn=default_dsn)

# %%
async with await db.connection() as conn:
    data = await conn.query('SELECT * FROM walmart.stores')
# Out:
# [DEBUG] 2024-05-17 15:31:53,834 DB.pg|582 ::                 Initialized on: 1715952713.8346984
# [DEBUG] 2024-05-17 15:31:53,834 DB.pg(pg.py:582) :: Initialized on: 1715952713.8346984

# %%
# Out:
# [[<Record store_id=1111 region_id=21 market_id=212 store_sap='01111' location_code='57124' launch_date=datetime.date(2018, 4, 18) effective_date=datetime.date(2018, 10, 1) move_date=datetime.date(2022, 6, 1) state_code='GA' street_address='1572 ANDERSON HWY' city_id=5482 city='HARTWELL' zipcode='30643' country_id=236 phone='(706) 376-5400' latitude=34.349611 longitude=-82.904924 type_id=1 store_name='HARTWELL-WM - #1111' store_status=True is_legacy=True legacy_market=143 legacy_region=14 legacy_company=1 legacy_launch_date=datetime.date(2018, 4, 18) territory_id=2 carrier_mix='Yes' country_code='US' city_name='HARTWELL' territory_name='2' region_name='21-NE Georgia' market_name='212-Channel' company_id=1 program_id=3 closed_date=None carrier_count=2 launch_group='2018' store_tier='B' allocated_hours=72 cluster_id=None cluster_name=None district_id=212 district_name='NE Georgia-212' carrier_list=['Yes', None]>, <Record store_id=1123 region_id=21 market_id=212 store_sap='01123' locatio
# ...
